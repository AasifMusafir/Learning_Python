# %% [markdown]
# #Encapsulation
# **Encapsulation means hiding internal details of a class and only exposing what’s necessary. It helps to protect important data from being changed directly and keeps the code secure and organized.**

# %% [markdown]
# **Why do we need Encapsulation?**
#
# 1.Protects data from unauthorized access and accidental modification.
#
# 2.Controls data updates using getter/setter methods with validation.
#
# 3.Enhances modularity by hiding internal implementation details.
#
# 4.Simplifies maintenance through centralized data handling logic.
#
# 5.Reflects real-world scenarios like restricting direct access to a bank account balance.

# %% [markdown]
# **Access Specifiers**
#
# Access specifiers define how class members(variables and methods) can be acccesed from outside of the class
#
# There are three types ofaccess specifiers:
#
# 1.Public specifiers(self.name)
#
# 2.Private specifiers(_self.name)
#
# 3.Protected specifiers(__self.name)

# %% [markdown]
# **Public Members**
#
# Public members are variables and methods that can be accessed anywhere inside the class,outside the class from other modules,By default every members are public members

# %% [markdown]
# **Protected Members**
#
# Private members are variables and methods that can be accessed only inside the class and its subclass,They are not strictly private but should be treated as internal.

# %% [markdown]
# **Private Members**
#
# Private members are variables or methods that cannot be accessed directly from outside the class. They are used to restrict access and protect internal data.

# %%
#Example
class Animal:
  def __init__(self,name,age,color,breed):
    self.name=name
    self.age=age
    self._color=color
    self.__breed=breed

  def behaviour(self):
    print(f"The age of the cat is {self.age}")

Cat=Animal("meow",2,"black","indian")
Cat.behaviour()
print(Cat._color)
# Out:
# The age of the cat is 2
# black

# %%
class dog(Animal):

  def __init__(self,name,age,color,breed):
    super().__init__(name, age, color, breed)
    print(f"the age of the dog is {self.age}")

Dog=Animal("woof",3,"white","German")
print(Dog._color)
# Out:
# white
