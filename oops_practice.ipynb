# %%
#Develop a class Calculator with methods to add and subtract two numbers.

class calculator:
    def add(self,a,b):
        return a+b
    
    def subtract(self,a,b):
        return a-b


ex1=calculator()

print(ex1.add(5,6))
print(ex1.subtract(50,10))
# Out:
# 11
# 40

# %%
# Build a class Employee with multiple constructors that can initialize an employee object in different ways.

class Employee:
    def __init__(self,name="Asif",id=0,age=18,department="HR"):
        self.name=name
        self.id=id
        self.age=age
        self.department=department

    def display_details(self):
        print(f"{self.name} is from {self.department} and the employee id is {self.id} and age is {self.age}")

    def branch(self):
        print(f"the person {self.name} belongs to {self.department}")


employee1=Employee("Asif",36,23,"IT")
employee1.display_details()

employee1.branch()
# Out:
# Asif is from IT and the employee id is 36 and age is 23
# the person Asif belongs to IT

# %%
#Create a class MaxFinder that identifies the largest number in a list.

class Maxfinder:
    def __init__(self,numbers):
        self.numbers=numbers

    def maximum(self):
        if not self.numbers:
            return "List is empty"
        return max(self.numbers)
    
num=Maxfinder([1,2,43,435,5])
print(num.maximum())
# Out:
# 435

# %%
#Create a Bus class that inherits from the Vehicle class. Give the capacity argument of Bus.seating_capacity() a default value of 50.

class Vehicle:
    def __init__(self,model,color,capacity):
        self.model=model
        self.color=color
        self.capacity=capacity
    
    def seating(self):
        return f"the capacity of the vehicle is {self.capacity}"

class Bus(Vehicle):
    def __init__(self,model,color,capacity=50):
        super().__init__(model,color,capacity)
   

      
volvo=Vehicle("2023","black",100)
print(volvo.seating())

bmw=Bus("20234","white")
print(bmw.seating())
# Out:
# the capacity of the vehicle is 100
# the capacity of the vehicle is 50

# %%
#Define a class attribute”color” with a default value white. I.e., Every Vehicle should be white.

class Vehicle:
    color="white"

    def __init__(self,mileage,max_speed,engine):
        self.mileage=mileage
        self.max_speed=max_speed
        self.engine=engine
    
class Bus(Vehicle):
    pass

class car(Vehicle):
    pass

bmw=Vehicle(50,150,"petrol")
volvo=Vehicle(40,122,"diesel")

print(f"the color of vehicle is {bmw.color} and the mileage is {bmw.mileage}")
print(f"the color of the the vehicle is {volvo.color} and the max speed is {bmw.max_speed}")
# Out:
# the color of vehicle is white and the mileage is 50
# the color of the the vehicle is white and the max speed is 150
